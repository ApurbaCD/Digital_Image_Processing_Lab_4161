# %%
import matplotlib.pyplot as plt
import cv2
def main():
    img_path1 = '/home/apd/code/CSE_Lab/CSE_4_1_DIP/DIP/Image/image38.jpg'
    img_path2 = '/home/apd/code/CSE_Lab/CSE_4_1_DIP/DIP/Image/image4.jpg'
    
    img1 = plt.imread(img_path1)
    img2 = plt.imread(img_path2)

    img1=cv2.resize(img1, (256, 256))
    img2=cv2.resize(img2, (256, 256))
    
    # add 2 picture
    img4=img1+img2
    # print(img4.shape)
    # print(img4)
      
    plt.figure(figsize=(12,8))
    plt.subplot(1,2,1)
    plt.imshow(img1)
    plt.title('Original Image')
    
    
    #make a black box inside the 
    for i in range(100):
        for j in range(100):
           img1[i,j]=0
    
    
    plt.subplot(1,2,2)
    plt.imshow(img1)
    plt.title('Transfered Image')
    plt.show()

if __name__=='__main__':
    main()
